# %% [markdown]
# <h1 align="center" style="font-size:40px"> ETUDE ENERGETIQUE D'UN MOUVEMENT </h1>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **CONSIGNES GENERALES**
#
# * Bien lire les consignes dans les cadres bleus.
# * Avant de passer à la questions suivante, penser à exécuter la cellule de code modifiée
# * En cas de blocage trop important, regarder la solution et copier / coller le code
# * N'exécuter que la cellule contenant les résultats du mouvement choisi.
# </div>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# **Consignes**
# * Exécuter la cellule 0 pour importer les modules nécessaires.
# * Exécuter la cellule 1 pour étudier le mouvement de la balle de golf.
# * Exécuter la cellule 2 pour le mouvement du pendule dans l'air
# * Exécuter la cellule 3 pour le mouvement du pendule dans l'eau.
# </div>

# %%
### Cellule 0 : importation des modules ###
import matplotlib.pyplot as plt
from math import *

# %%
### Cellule 1 : balle de golf ###

y = [0.004031963073, 0.3023972305, 0.5422990333, 0.7459131685, 0.8950958022, 1.007990768, 1.074518159, 1.092661993, 1.07653414, 1.005974787, 0.9011437468, 0.7418812054, 0.5584268856, 0.304413212]
x = [0.0, 0.1491826337, 0.3084451751, 0.4616597718, 0.6128583871, 0.7620410208, 0.9192875806, 1.06242227, 1.215636866, 1.362803519, 1.516018115, 1.673264675, 1.816399364, 1.973645924]
t = [0.0, 0.066667, 0.133334, 0.200001, 0.266668, 0.333335, 0.400002, 0.466669, 0.533336, 0.600003, 0.66667, 0.733337, 0.800004, 0.866671]

# %%
### Cellule 2 : pendule dans l'air ###
y = [-0.001102047926, 0.0002129984766, 0.004291424206, 0.0118311638, 0.01868573033, 0.01445842072, 0.04141271269, 0.05037100843, 0.05451465948, 0.04554785609, 0.03797408589, 0.02971939645, 0.02216264156, 0.01461439431, 0.009144353327, 0.005058837889, 0.00300757252, 0.008647766509, 0.01556046865, 0.02182628215, 0.02947378532, 0.03641342835, 0.0419671279, 0.04751090185, 0.05027995294, 0.04889684534, 0.04474043281, 0.0385015602, 0.0308696544, 0.023227823, 0.01627258261, 0.009305998682, 0.004413367192, 0.004346723932, 0.006356868992, 0.01251491892, 0.01868714827, 0.02554880451, 0.03380632983, 0.03999841037, 0.04550531783, 0.04826018951, 0.0489496164, 0.04619474472, 0.0413758462, 0.03518518361, 0.026934748, 0.02006742, 0.01321143552, 0.007050549707, 0.004345305991, 0.005793638914, 0.008610900025, 0.01349785975, 0.02253272434, 0.02947945708, 0.036421936, 0.04266080861, 0.04682005702, 0.04751657361, 0.04682147496, 0.04197279966, 0.036421936, 0.02809918536, 0.01906715665, 0.01280559697, 0.006528439938, 0.003014662229, 0.002950854852, 0.006344107517, 0.0125106651, 0.01867864062, 0.0262382314, 0.03380349395, 0.04068641931, 0.04550673578, 0.04757218056, 0.04688275367, 0.04412646405, 0.04000124625, 0.03380916572, 0.02624532111, 0.01800055727, 0.01045231002, 0.005673113869, 0.003661550868, 0.005101376141, 0.008617989733, 0.01489372883, 0.02184471539
t = [0.2669333333, 0.3003, 0.3336666667, 0.3670333333, 0.4004, 0.4337666667, 0.4671333333, 0.5005, 0.5338666667, 0.5672333333, 0.6006, 0.6339666667, 0.6673333333, 0.7007, 0.7340666667, 0.7674333333, 0.8008, 0.8341666667, 0.8675333333, 0.9009, 0.9342666667, 0.9676333333, 1.001, 1.034366667, 1.067733333, 1.1011, 1.134466667, 1.167833333, 1.2012, 1.234566667, 1.267933333, 1.3013, 1.334666667, 1.368033333, 1.4014, 1.434766667, 1.468133333, 1.5015, 1.534866667, 1.568233333, 1.6016, 1.634966667, 1.668333333, 1.7017, 1.735066667, 1.768433333, 1.8018, 1.835166667, 1.868533333, 1.9019, 1.935266667, 1.968633333, 2.002, 2.035366667, 2.068733333, 2.1021, 2.135466667, 2.168833333, 2.2022, 2.235566667, 2.268933333, 2.3023, 2.335666667, 2.369033333, 2.4024, 2.435766667, 2.469133333, 2.5025, 2.535866667, 2.569233333, 2.6026, 2.635966667, 2.669333333, 2.7027, 2.736066667, 2.769433333, 2.8028, 2.836166667, 2.869533333, 2.9029, 2.936266667, 2.969633333, 3.003, 3.036366667, 3.069733333, 3.1031, 3.136466667, 3.169833333, 3.2032, 3.236566667, 3.269933333, 3.3033, 3.336666667, 3.370033333, 3.4034, 3.436766667, 3.470133333, 3.5035, 3.536866667, 3.570233333, 3.6036, 3.636966667, 3.670333333, 3.7037, 3.737066667, 3.770433333, 3.8038]

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# **Consignes**
# * Compléter le code de manière à obtenir la valeur de la vitesse au point $M_i$
# </div>

# %%
def vitesse(x, y,t, i):
    '''Fonction prenant en argument des listes de coordonnées spatiales et de dates x, y, t, et l'indice i dont on veut connaitre la vitesse.
    Elle renvoie la valeur de la vitesse correspondant.'''
    dt = t[2] - t[1]
    vx_i = (...) / (...)
    vy_i = (...) / (...)
    vit_i = sqrt(... + ...)
    return vit_i

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <details>
#         <summary> <b> Aides </b> </summary>
#
# * Le calcul approché de la vitesse instantannée se fait avec les coordonnées des points suivant et points précédent.
# * Attention à la durée écoulée entre les points considérés.
# * la norme d'un vecteur est la racine carré de la somme des carrés de ses coodonnées.
#     </details>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#  <details>
#         <summary> <b> Solution </b> </summary>
#
# * **Ligne 5 :** vx_i = (x[i+1] - x[i-1]) / (2 * dt)
# * **Ligne 6 :** vy_i = (y[i+1] - y[i-1]) / (2 * dt)
# * **Ligne 7 :** vit_i = sqrt(vx_i ** 2 + vy_i ** 2)
#     </details>
# </div>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# **Consignes**
#
# * Compléter les lignes 12, 13, 14, 15 pour calculer la vitesse et les différentes énergie à la date $t_i$.
# * Compléter les lignes 16, 17, 18 pour ajouter les valeurs précédentes aux listes Ec, Epp et Em
#
# </div>

# %%
# données expérimentales
m = ... # kg
g = 9.81 # N/kg

N = ... # Nb de points expérimentaux
#Initialisation des listes
Ec = []
Epp = []
Em = []
#Remplissage des listes
for i in range(1,N-1): # Pas le dernier point et le premier point
    v_i = ...
    Ec_i = ...
    Epp_i = ...
    
    Ec.append(...)                       
    Epp.append(...)                       
    Em.append(...)

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <details>
#         <summary> <b> Aides </b> </summary>
#         <ul>
#             <li> <b> Ligne 12 : </b> Il faut appeler la fonction vitesse définie précédemment. </li>
#             <li> <b> Ligne 13 : </b> Revoir la définition de l'énergie cinétique et utiliser la valeur de la vitesse calculée la ligne précédente. </li>
#             <li> <b> Ligne 14 : </b> Revoir la définition de l'énergie potentielle de pesanteur et penser qu'on a besoin de la valeur de la liste y d'indice i. </li>
#             <li> <b> Ligne 16, 17, 18 : </b> Pour calculer une nouvelle grandeur, voir  la notice <a href="https://nuage-creteil.beta.education.fr/s/XisdgRc2MtEw7WZ?dir=undefined&path=%2FNotices%2FPython%2FNotice_python_graph&openfile=20451"> pdf </a> ou le <a href="https://tube-creteil.beta.education.fr/videos/watch/8ba61fa9-08ac-4e32-947b-dbcafc736fa6"> tuto vidéo </a> </li>
#         </ul>
#     </details>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#  <details>
#         <summary> <b> Solution </b> </summary>
#         <ul>
#             <li> <b> Ligne 12 : </b> v_i = vitesse(x,y,t,i) </li>
#             <li> <b> Ligne 13 : </b> Ec_i = .5 * m * v_i**2 </li>
#             <li> <b> Ligne 14 : </b> Epp_i = m *g * y[i] </li>
#             <li> <b> Ligne 16 : </b> Ec.append(Ec_i) </li>
#             <li> <b> Ligne 17 : </b> Epp.append(Epp_i) </li>
#             <li> <b> Ligne 18 : </b> Em.append(Ec_i + Epp_i) </li>
#         </ul>
#     </details>
# </div>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# **Consignes**
#
# Exécuter la cellule et passer à la suite.
#
# </div>

# %%
t = t[1:-1] # On supprime la 1ere  et la dernière date car aucune énergie n'y est calculée

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# **Consignes**
#
# Compléter les lignes la cellule pour tracer la variation des différentes énergies en fonction du temps.
#
# </div>

# %%
plt.plot(..., ...,'o', label="Ec")                   
plt.plot(..., ...,'o', label="Epp")              
plt.plot(...,... , 'o', label="Em")                   
plt.grid()
plt.legend()
plt.xlim(0)
plt.ylim(0)
plt.xlabel("...")                        
plt.ylabel("...")                   
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <details>
#         <summary> <b> Aides </b> </summary>
#     <p> Pas d'aide ici! Vous devriez pouvoir vous débrouiller avec la notice <a href="https://nuage-creteil.beta.education.fr/s/XisdgRc2MtEw7WZ?dir=undefined&path=%2FNotices%2FPython%2FNotice_python_graph&openfile=20451"> pdf </a> ou le <a href="https://tube-creteil.beta.education.fr/videos/watch/8ba61fa9-08ac-4e32-947b-dbcafc736fa6"> tuto vidéo </a>
#     </details>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#  <details>
#         <summary> <b> Solution </b> </summary>
#         <ul>
#             <li> <b> Ligne 1 : </b> plt.plot(t, Ec,'o-', label="Ec")  </li>
#             <li> <b> Ligne 2 : </b> plt.plot(t, Epp,'o-', label="Epp") </li>
#             <li> <b> Ligne 3 : </b> plt.plot(t, Em, 'o-', label="Em") </li>
#             <li> <b> Ligne 8: </b> plt.xlabel("t/s") </li>
#             <li> <b> Ligne 9: </b> Epp.append("E/J") </li>
#         </ul>
#     </details>
# </div>
